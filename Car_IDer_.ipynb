# %% [markdown]
# <a href="https://colab.research.google.com/github/dphents/CarID/blob/master/Car_IDer_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastbook
# !pip install fastcore
# !pip install bing-image-downloader
from bing_image_downloader import downloader
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 7.1MB/s
#      |████████████████████████████████| 1.0MB 24.6MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#      |████████████████████████████████| 358kB 52.8MB/s
#      |████████████████████████████████| 51kB 5.5MB/s
#      |████████████████████████████████| 40kB 4.7MB/s
#      |████████████████████████████████| 92kB 12.0MB/s
#      |████████████████████████████████| 40kB 5.6MB/s
#      |████████████████████████████████| 61kB 8.4MB/s
#      |████████████████████████████████| 51kB 7.3MB/s
#      |████████████████████████████████| 2.6MB 51.3MB/s
# Requirement already satisfied: fastcore in /usr/local/lib/python3.6/dist-packages (1.0.15)
# Requirement already satisfied: pip in /usr/local/lib/python3.6/dist-packages (from fastcore) (19.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastcore) (20.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->fastcore) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastcore) (2.4.7)
# Collecting bing-image-downloader
#   Downloading https://files.pythonhosted.org/packages/0d/bf/537a61030b84ae4cd5022d5c7b014fd9bc3ce7c02358919153a6658a61d3/bing_image_downloader-1.0.4-py3-none-any.whl
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.0.4
# Mounted at /content/gdrive

# %%
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# Initializes bing API Key that will be used later for the image searching.

# %%
key = '5b24868f8fe749e381a9ad2f5ed3fbfb'
search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %% [markdown]
# Imports csv with all car makes and models from EPA database, then prints the list (cars).

# %%
import csv

cardb = []

with open('/content/gdrive/My Drive/Cars.csv', newline='') as csvfile:
  carinfo = csv.reader(csvfile, delimiter=' ', quotechar='|')
  for row in carinfo:
   cardb.append(' '.join(row))


cardb
# Out:
# ['\ufeff1985 Alfa Romeo Spider Veloce 2000',
#  '1985 Ferrari Testarossa',
#  '1985 Dodge Charger',
#  '1985 Dodge B150 B250 Wagon 2WD',
#  '1993 Subaru Legacy AWD Turbo',
#  '1993 Subaru Loyale',
#  '1993 Subaru Loyale',
#  '1993 Toyota Corolla',
#  '1993 Toyota Corolla',
#  '1993 Toyota Corolla',
#  '1993 Toyota Corolla',
#  '1993 Volkswagen Golf III   GTI',
#  '1993 Volkswagen Golf III   GTI',
#  '1993 Volkswagen Jetta III',
#  '1985 Dodge B150 B250 Wagon 2WD',
#  '1993 Volkswagen Jetta III',
#  '1993 Volvo 240',
#  '1993 Volvo 240',
#  '1993 Audi 100',
#  '1993 Audi 100',
#  '1993 BMW 740i',
#  '1993 BMW 740il',
#  '1993 BMW 750il',
#  '1993 Buick Century',
#  '1993 Buick Century',
#  '1985 Dodge B150 B250 Wagon 2WD',
#  '1993 Buick Century',
#  '1993 Buick Regal',
#  '1993 Buick Regal',
#  '1993 Buick Regal',
#  '1993 Buick Riviera',
#  '1993 Cadillac Eldorado',
#  '1993 Cadillac Eldorado',
#  '1993 Cadillac Seville',
#  '1993 Cadillac Seville',
#  '1993 Chevrolet Lumina',
#  '1985 Dodge B150 B250 Wagon 2WD',
#  '1993 Chevrolet Lumina',
#  '1993 Chevrolet Lumina',
#  '1993 Chevrolet Lumina',
#  '1993 Chevrolet Lumina',
#  '1993 Chrysler New Yorker',
#  '1993 CX Automotive XM v6',
#  '1993 CX Automotive XM v6a',
#  '1993 Nissan Maxima',
#  '1993 Nissan Maxima',
#  '1993 Nissan Maxima',
#  '1985 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge Dynasty',
#  '1993 Dodge Dynasty',
#  '1993 Dodge Dynasty',
#  '1993 Dodge Spirit',
#  '1993 Dodge Spirit',
#  '1993 Dodge Spirit',
#  '1993 Dodge Spirit',
#  '1993 Dodge Spirit',
#  '1993 Ford Taurus',
#  '1993 Ford Taurus SHO',
#  '1985 Dodge B350 Wagon 2WD',
#  '1993 Ford Taurus',
#  '1993 Ford Thunderbird',
#  '1993 Ford Thunderbird',
#  '1993 Ford Thunderbird',
#  '1993 Ford Thunderbird',
#  '1993 Hyundai Sonata',
#  '1993 Hyundai Sonata',
#  '1993 Hyundai Sonata',
#  '1993 Infiniti Q45',
#  '1993 Infiniti Q45 Full-Active Suspension',
#  '1985 Dodge B350 Wagon 2WD',
#  '1993 Lexus LS 400',
#  '1993 Mercury Cougar',
#  '1993 Mercury Cougar',
#  '1993 Mercury Sable',
#  '1993 Mercury Sable',
#  '1993 Mazda 626',
#  '1993 Mazda 626',
#  '1993 Mazda 626',
#  '1993 Mazda 626',
#  '1993 Mazda 929',
#  '1985 Dodge B350 Wagon 2WD',
#  '1993 Oldsmobile Cutlass Ciera',
#  '1993 Oldsmobile Cutlass Ciera',
#  '1993 Oldsmobile Cutlass Ciera',
#  '1993 Oldsmobile Cutlass Supreme',
#  '1993 Oldsmobile Cutlass Supreme',
#  '1993 Oldsmobile Cutlass Supreme',
#  '1993 Oldsmobile Cutlass Supreme',
#  '1993 Oldsmobile Toronado',
#  '1993 Plymouth Acclaim',
#  '1993 Plymouth Acclaim',
#  '1985 Ford E150 Club Wagon',
#  '1993 Plymouth Acclaim',
#  '1993 Plymouth Acclaim',
#  '1993 Plymouth Acclaim',
#  '1993 Pontiac Grand Prix',
#  '1993 Pontiac Grand Prix',
#  '1993 Pontiac Grand Prix',
#  '1993 Pontiac Grand Prix',
#  '1993 Rolls-Royce Brooklands Brklnds L',
#  '1993 Rolls-Royce Turbo R Turbo R(lwb)',
#  '1993 Rolls-Royce Silver Spirit II Silver Spur',
#  '1985 Ford E150 Club Wagon',
#  '1993 Toyota Camry',
#  '1993 Toyota Camry',
#  '1993 Toyota Camry',
#  '1993 Toyota Camry',
#  '1993 Volkswagen Passat',
#  '1993 Volkswagen Passat',
#  '1993 Volkswagen Passat',
#  '1993 Volkswagen Passat',
#  '1993 Volvo 850',
#  '1993 Volvo 850',
#  '1985 Dodge Charger',
#  '1985 Ford E150 Club Wagon',
#  '1993 Volvo 940',
#  '1993 Volvo 940',
#  '1993 Volvo 960',
#  '1993 Buick LeSabre',
#  '1993 Buick Park Avenue',
#  '1993 Buick Park Avenue',
#  '1993 Buick Roadmaster',
#  '1993 Cadillac DeVille 60 Special',
#  '1993 Cadillac Fleetwood',
#  '1993 Chevrolet Caprice',
#  '1985 Ford E150 Club Wagon',
#  '1993 Chevrolet Caprice',
#  '1993 Chevrolet Caprice',
#  '1993 Chrysler Concorde',
#  '1993 Chrysler Concorde',
#  '1993 Chrysler Fifth Avenue Imperial',
#  '1993 Chrysler Fifth Avenue Imperial',
#  '1993 Dodge Intrepid',
#  '1993 Dodge Intrepid',
#  '1993 Eagle Vision',
#  '1993 Eagle Vision',
#  '1985 Ford E150 Club Wagon',
#  '1993 Ford LTD Crown Victoria',
#  '1993 Lincoln Continental',
#  '1993 Mercury Grand Marquis',
#  '1993 Lincoln Town Car',
#  '1993 Mercedes-Benz 300SD',
#  '1993 Mercedes-Benz 300SE',
#  '1993 Mercedes-Benz 400SEL',
#  '1993 Mercedes-Benz 500SEL',
#  '1993 Oldsmobile Eighty-Eight',
#  '1993 Oldsmobile Ninety-Eight',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Oldsmobile Ninety-Eight',
#  '1993 Pontiac Bonneville',
#  '1993 Pontiac Bonneville',
#  '1993 Rolls-Royce Silver Spur II Mpw Touring L',
#  '1993 Saab 9000',
#  '1993 Saab 9000',
#  '1993 Saab 9000',
#  '1993 Saab 9000',
#  '1993 Audi 100 quattro Wagon',
#  '1993 BMW 525i Touring',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Chevrolet Cavalier Wagon',
#  '1993 Chevrolet Cavalier Wagon',
#  '1993 CX Automotive XM v6 Break',
#  '1993 Ford Escort Wagon',
#  '1993 Ford Escort Wagon',
#  '1993 Honda Accord Wagon',
#  '1993 Honda Accord Wagon',
#  '1993 Mercury Tracer Wagon',
#  '1993 Mercury Tracer Wagon',
#  '1993 Saturn SW',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Saturn SW',
#  '1993 Saturn SW',
#  '1993 Saturn SW',
#  '1993 Subaru Legacy Wagon',
#  '1993 Subaru Legacy Wagon',
#  '1993 Subaru Legacy Wagon AWD',
#  '1993 Subaru Legacy Wagon AWD',
#  '1993 Subaru Legacy Wagon AWD Turbo',
#  '1993 Subaru Loyale Wagon',
#  '1993 Subaru Loyale Wagon',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Toyota Corolla Wagon',
#  '1993 Toyota Corolla Wagon',
#  '1993 Buick Century Wagon',
#  '1993 Buick Century Wagon',
#  '1993 Buick Century Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Eagle Summit Wagon',
#  '1993 Ford Taurus Wagon',
#  '1993 Ford Taurus Wagon',
#  '1993 Mercury Sable Wagon',
#  '1993 Mercury Sable Wagon',
#  '1993 Mitsubishi Expo',
#  '1993 Mitsubishi Expo',
#  '1993 Mitsubishi Expo',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Mitsubishi Expo',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Mitsubishi Expo.LRV',
#  '1993 Oldsmobile Cutlass Cruiser',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Oldsmobile Cutlass Cruiser',
#  '1993 Oldsmobile Cutlass Cruiser',
#  '1993 Mitsubishi Diamante Wagon',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1993 Plymouth Colt Vista',
#  '1985 Dodge Charger',
#  '1985 GMC G15 25 Rally 2WD',
#  '1993 Plymouth Colt Vista',
#  '1993 Toyota Camry Wagon',
#  '1993 Toyota Camry Wagon',
#  '1993 Volkswagen Passat Wagon',
#  '1993 Volkswagen Passat Wagon',
#  '1993 Volkswagen Passat Wagon',
#  '1993 Volkswagen Passat Wagon',
#  '1993 Volvo 240 Wagon',
#  '1993 Volvo 240 Wagon',
#  '1993 Volvo 940 Wagon',
#  '1985 GMC G35 Rally 2WD',
#  '1993 Volvo 940 Wagon',
#  '1993 Volvo 960 Wagon',
#  '1993 Buick Roadmaster Wagon',
#  '1993 Chevrolet Caprice Wagon',
#  '1993 Chevrolet Caprice Wagon',
#  '1993 Chevrolet S10 Pickup 2WD',
#  '1993 Chevrolet S10 Pickup 2WD',
#  '1993 Chevrolet S10 Pickup 2WD',
#  '1993 Chevrolet S10 Pickup 2WD',
#  '1993 Chevrolet S10 Pickup 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 Nissan Truck 2WD',
#  '1993 Nissan Truck 2WD',
#  '1993 Nissan Truck 2WD',
#  '1993 Dodge Ram 50 Pickup 2WD',
#  '1993 Dodge Ram 50 Pickup 2WD',
#  '1993 GMC Sonoma 2WD',
#  '1993 GMC Sonoma 2WD',
#  '1993 GMC Sonoma 2WD',
#  '1993 GMC Sonoma 2WD',
#  '1993 GMC Sonoma 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 GMC Sonoma 2WD',
#  '1993 Isuzu Pickup 2WD',
#  '1993 Isuzu Pickup 2WD',
#  '1993 Isuzu Pickup 2WD',
#  '1993 Mitsubishi Truck 2WD',
#  '1993 Mitsubishi Truck 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet C1500 Pickup 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Chevrolet Pickup 2500 2WD',
#  '1993 Dodge Dakota Pickup 2WD',
#  '1993 Dodge Dakota Pickup 2WD',
#  '1993 Dodge Dakota Pickup 2WD',
#  '1993 Dodge Dakota Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D100 D150 Pickup 2WD',
#  '1993 Dodge D250 Pickup 2WD',
#  '1993 Dodge D250 Pickup 2WD',
#  '1993 Dodge D250 Pickup 2WD',
#  '1993 Dodge D250 Pickup 2WD',
#  '1993 Dodge D250 Pickup 2WD',
#  '1985 GMC Safari 2WD (passenger)',
#  '1993 Dodge D250 Pickup 2WD',
#  '1993 Jeep Comanche Pickup 4WD',
#  '1993 Jeep Comanche Pickup 4WD',
#  '1993 Jeep Comanche Pickup 4WD',
#  '1993 Jeep Comanche Pickup 4WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1985 Toyota Van 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F150 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1993 Ford F250 Pickup 2WD',
#  '1985 Toyota Van 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 Ford Ranger Pickup 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1985 Dodge Colt',
#  '1985 Volkswagen Vanagon 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 1500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1985 Volkswagen Vanagon 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 GMC Sierra 2500 2WD',
#  '1993 Mazda B2200 B2600i',
#  '1993 Mazda B2200 B2600i',
#  '1993 Mazda B2200 B2600i',
#  '1993 Mazda B2200 B2600i',
#  '1993 Mazda B2200 B2600i',
#  '1993 Mazda B2200 B2600i',
#  '1993 Toyota T100 2WD',
#  '1985 AM General Post Office DJ5 2WD',
#  '1993 Toyota T100 2WD',
#  '1993 Toyota T100 2WD',
#  '1993 Toyota T100 2WD',
#  '1993 Toyota T100 2WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1985 AM General Post Office DJ8 2WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet K1500 Pickup 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1985 Chevrolet Suburban C10 2WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet Pickup 2500 4WD',
#  '1993 Chevrolet S10 Pickup 4WD',
#  '1993 Chevrolet S10 Pickup 4WD',
#  '1993 Nissan Truck 4WD',
#  '1993 Nissan Truck 4WD',
#  '1993 Nissan Truck 4WD',
#  '1993 Dodge Dakota Pickup 4WD',
#  '1993 Dodge Dakota Pickup 4WD',
#  '1993 Dodge Dakota Pickup 4WD',
#  '1985 Chevrolet Suburban C10 2WD',
#  '1993 Dodge Power Ram 50 4WD',
#  '1993 Dodge Power Ram 50 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W100 W150 Pickup 4WD',
#  '1993 Dodge W250 Pickup 4WD',
#  '1993 Dodge W250 Pickup 4WD',
#  '1985 Chevrolet Suburban C10 2WD',
#  '1993 Dodge W250 Pickup 4WD',
#  '1993 Dodge W250 Pickup 4WD',
#  '1993 Jeep Comanche Pickup 2WD',
#  '1993 Jeep Comanche Pickup 2WD',
#  '1993 Jeep Comanche Pickup 2WD',
#  '1993 Jeep Comanche Pickup 2WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford F150 Pickup 4WD',
#  '1993 Ford Ranger Pickup 4WD',
#  '1993 Ford Ranger Pickup 4WD',
#  '1993 Ford Ranger Pickup 4WD',
#  '1993 Ford Ranger Pickup 4WD',
#  '1993 Ford Ranger Pickup 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 1500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sierra 2500 4WD',
#  '1993 GMC Sonoma 4WD',
#  '1993 GMC Sonoma 4WD',
#  '1993 GMC Sonoma 4WD',
#  '1985 Dodge Colt',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 Isuzu Pickup 4WD',
#  '1993 Isuzu Pickup 4WD',
#  '1993 Mitsubishi Truck 4WD',
#  '1993 Mitsubishi Truck 4WD',
#  '1993 Mitsubishi Truck 4WD',
#  '1993 Mazda B2600i 4x4',
#  '1993 Mazda B2600i 4x4',
#  '1993 Toyota Truck 4WD T100 4WD',
#  '1993 Toyota Truck 4WD T100 4WD',
#  '1993 Toyota Truck 4WD T100 4WD',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 Toyota Truck 4WD T100 4WD',
#  '1993 Toyota Truck 4WD T100 4WD',
#  '1993 Chevrolet Astro AWD (cargo)',
#  '1993 Chevrolet Astro 2WD (cargo)',
#  '1993 Chevrolet Astro 2WD (cargo)',
#  '1993 Chevrolet G10 20 Van 2WD',
#  '1993 Chevrolet G10 20 Van 2WD',
#  '1993 Chevrolet G10 20 Van 2WD',
#  '1993 Chevrolet G30 Van 2WD',
#  '1993 Chevrolet G30 Van 2WD',
#  '1985 Chevrolet S10 Blazer 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B150 B250 Van 2WD',
#  '1993 Dodge B350 Van 2WD',
#  '1993 Dodge B350 Van 2WD',
#  '1993 Dodge B350 Van 2WD',
#  '1993 Ford Aerostar Van',
#  '1985 Dodge AD100 AD150 Ramcharger 2WD',
#  '1993 Ford Aerostar Van',
#  '1993 Ford Aerostar Van',
#  '1993 Ford Aerostar Van AWD',
#  '1993 Ford E150 Econoline 2WD',
#  '1993 Ford E150 Econoline 2WD',
#  '1993 Ford E150 Econoline 2WD',
#  '1993 Ford E150 Econoline 2WD',
#  '1993 Ford E150 Econoline 2WD',
#  '1993 Ford E250 Econoline 2WD',
#  '1993 Ford E250 Econoline 2WD',
#  '1985 Dodge AD100 AD150 Ramcharger 2WD',
#  '1993 Ford E250 Econoline 2WD',
#  '1993 GMC Vandura G15 25 2WD',
#  '1993 GMC Vandura G15 25 2WD',
#  '1993 GMC Vandura G15 25 2WD',
#  '1993 GMC Vandura G35 2WD',
#  '1993 GMC Vandura G35 2WD',
#  '1993 GMC Safari AWD (cargo)',
#  '1993 GMC Safari 2WD (cargo)',
#  '1993 GMC Safari 2WD (cargo)',
#  '1993 Chevrolet Astro AWD (passenger)',
#  '1985 Dodge AD100 AD150 Ramcharger 2WD',
#  '1993 Chevrolet Astro 2WD (passenger)',
#  '1993 Chevrolet Astro 2WD (passenger)',
#  '1993 Chevrolet Sport Van G10 20 2WD',
#  '1993 Chevrolet Sport Van G10 20 2WD',
#  '1993 Chevrolet Sport Van G10 20 2WD',
#  '1993 Chevrolet Sport Van G30 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1985 Dodge AD100 AD150 Ramcharger 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge B150 B250 Wagon 2WD',
#  '1993 Dodge B350 Wagon 2WD',
#  '1993 Dodge B350 Wagon 2WD',
#  '1993 Ford Aerostar Wagon',
#  '1993 Ford Aerostar Wagon',
#  '1993 Ford Aerostar Wagon',
#  '1993 Ford Aerostar Wagon AWD',
#  '1993 Ford E150 Club Wagon',
#  '1993 Ford E150 Club Wagon',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Ford E150 Club Wagon',
#  '1993 Ford E150 Club Wagon',
#  '1993 GMC Rally G15 25 2WD',
#  '1993 GMC Rally G15 25 2WD',
#  '1993 GMC Rally G15 25 2WD',
#  '1993 GMC Rally G35 2WD',
#  '1993 GMC Safari AWD (passenger)',
#  '1993 GMC Safari 2WD (passenger)',
#  '1993 GMC Safari 2WD (passenger)',
#  '1993 Toyota Previa',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Toyota Previa',
#  '1993 Toyota Previa All-Trac',
#  '1993 Volkswagen Eurovan',
#  '1993 Volkswagen Eurovan',
#  '1993 Chevrolet Lumina APV Minivan 2WD',
#  '1993 Chevrolet Lumina APV Minivan 2WD',
#  '1993 Chevrolet Suburban 1500 2WD',
#  '1993 Chevrolet S10 Blazer 2WD',
#  '1993 Chevrolet S10 Blazer 2WD',
#  '1993 Nissan Pathfinder 2WD',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Nissan Pathfinder 2WD',
#  '1993 Nissan Quest',
#  '1993 Chrysler Town and Country 2WD',
#  '1993 Dodge Caravan C V Grand Caravan 2WD',
#  '1993 Dodge Caravan C V Grand Caravan 2WD',
#  '1993 Dodge Caravan C V Grand Caravan 2WD',
#  '1993 Dodge Caravan C V Grand Caravan 2WD',
#  '1993 Dodge Caravan Grand Caravan 2WD',
#  '1993 Dodge Caravan Grand Caravan 2WD',
#  '1993 Dodge Caravan Grand Caravan 2WD',
#  '1985 Dodge Colt',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Dodge Caravan Grand Caravan 2WD',
#  '1993 Dodge Ramcharger 2WD',
#  '1993 Dodge Ramcharger 2WD',
#  '1993 Jeep Cherokee 2WD',
#  '1993 Jeep Cherokee 2WD',
#  '1993 Jeep Cherokee 2WD',
#  '1993 Ford Explorer 2WD',
#  '1993 Ford Explorer 2WD',
#  '1993 Mercury Villager FWD Van',
#  '1993 Mercury Villager FWD Wagon',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Geo Tracker Convertible 2WD',
#  '1993 Geo Tracker Convertible 2WD',
#  '1993 GMC Suburban 1500 2WD',
#  '1993 GMC Jimmy 2WD',
#  '1993 GMC Jimmy 2WD',
#  '1993 Isuzu Amigo 2WD',
#  '1993 Isuzu Amigo 2WD',
#  '1993 Isuzu Amigo 2WD',
#  '1993 Isuzu Rodeo 2WD',
#  '1993 Mazda MPV',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Mazda MPV',
#  '1993 Pontiac Trans Sport 2WD',
#  '1993 Pontiac Trans Sport 2WD',
#  '1993 Plymouth Voyager Grand Voyager 2WD',
#  '1993 Plymouth Voyager Grand Voyager 2WD',
#  '1993 Plymouth Voyager Grand Voyager 2WD',
#  '1993 Plymouth Voyager Grand Voyager 2WD',
#  '1993 Suzuki Samurai 2WD',
#  '1993 Suzuki Sidekick Hardtop 2WD',
#  '1993 Suzuki Sidekick Hardtop 2WD',
#  '1985 Dodge Caravan Ram Van 2WD',
#  '1993 Suzuki Sidekick 2WD',
#  '1993 Suzuki Sidekick 2WD',
#  '1993 Oldsmobile Silhouette 2WD',
#  '1993 Oldsmobile Silhouette 2WD',
#  '1993 Toyota 4Runner 2WD',
#  '1993 Chevrolet Blazer 1500 4WD',
#  '1993 Chevrolet Blazer 1500 4WD',
#  '1993 Chevrolet Suburban 1500 4WD',
#  '1993 Chevrolet S10 Blazer 4WD',
#  '1993 Chevrolet S10 Blazer 4WD',
#  '"1985 E. P. Dutton, Inc. Funeral Coach"',
#  '1993 Nissan Pathfinder 4WD',
#  '1993 Nissan Pathfinder 4WD',
#  '1993 Chrysler Town and Country 4WD',
#  '1993 Dodge Caravan Grand Caravan 4WD',
#  '1993 Dodge Ramcharger 4WD',
#  '1993 Dodge Ramcharger 4WD',
#  '1993 Jeep Cherokee 4WD',
#  '1993 Jeep Cherokee 4WD',
#  '1993 Jeep Cherokee 4WD',
#  '1993 Jeep Grand Cherokee 4WD',
#  '1985 GMC C15 Suburban 2WD',
#  '1993 Jeep Grand Cherokee 4WD',
#  '1993 Jeep Grand Cherokee 4WD',
#  '1993 Jeep Grand Cherokee 4WD',
#  '1993 Jeep Grand Cherokee 4WD',
#  '1993 Jeep Wrangler 4WD',
#  '1993 Jeep Wrangler 4WD',
#  '1993 Jeep Wrangler 4WD',
#  '1993 Ford Bronco 4WD',
#  '1993 Ford Bronco 4WD',
#  '1993 Ford Bronco 4WD',
#  '1985 GMC C15 Suburban 2WD',
#  '1993 Ford Explorer 4WD',
#  '1993 Ford Explorer 4WD',
#  '1993 Geo Tracker Convertible 4WD',
#  '1993 Geo Tracker Convertible 4WD',
#  '1993 Geo Tracker Van 4WD',
#  '1993 Geo Tracker Van 4WD',
#  '1993 GMC Jimmy 4WD',
#  '1993 GMC Jimmy 4WD',
#  '1993 GMC Suburban 1500 4WD',
#  '1993 GMC Yukon 1500 4WD',
#  '1985 GMC C15 Suburban 2WD',
#  '1993 GMC Yukon 1500 4WD',
#  '1993 Isuzu Amigo 4WD',
#  '1993 Isuzu Trooper',
#  '1993 Isuzu Trooper',
#  '1993 Isuzu Trooper',
#  '1993 Isuzu Trooper',
#  '1993 Land Rover Defender 110',
#  '1993 Land Rover Range Rover County',
#  '1993 Land Rover Range Rover County LWB',
#  '1993 Mitsubishi Montero',
#  '1985 GMC S15 Jimmy 2WD',
#  '1993 Mitsubishi Montero',
#  '1993 Mazda MPV 4x4',
#  '1993 Mazda Navajo',
#  '1993 Mazda Navajo',
#  '1993 Mazda Navajo 4x4',
#  '1993 Mazda Navajo 4x4',
#  '"1993 PAS, Inc Pas-Typhoon"',
#  '1993 Plymouth Voyager Grand Voyager 4WD',
#  '1993 Subaru Loyale AWD',
#  '1993 Subaru Loyale AWD',
#  '1985 GMC S15 Jimmy 2WD',
#  '1993 Subaru Loyale Wagon AWD',
#  '1993 Subaru Loyale Wagon AWD',
#  '1993 Suzuki Samurai Soft-top 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Hardtop 4WD',
#  '1993 Suzuki Sidekick Soft-top 4WD',
#  '1985 Dodge Colt',
#  '1985 GMC S15 Jimmy 2WD',
#  '1993 Suzuki Sidekick Soft-top 4WD',
#  '1993 Oldsmobile Bravada AWD',
#  '1993 Toyota Land Cruiser Wagon 4WD',
#  '1993 Toyota 4Runner 4WD',
#  '1993 Toyota 4Runner 4WD',
#  '1993 Toyota 4Runner 4WD',
#  '1993 Toyota 4Runner 4WD',
#  '1993 Cadillac Commercial Chassis',
#  '1993 Chevrolet Coachbuilder Wagon',
#  '1993 Chevrolet Postal Cab Chassis 2WD',
#  '1985 GMC S15 Jimmy 2WD',
#  '1993 Dodge Dakota Cab Chassis 2WD',
#  '1993 Dodge Dakota Cab Chassis 2WD',
#  '1993 Dodge Dakota Cab Chassis 2WD',
#  '1993 Dodge D250 Cab Chassis 2WD',
#  '1993 Buick Coachbuilder Wagon',
#  '1993 Toyota Cab Chassis 2WD',
#  '1993 Toyota Cab Chassis 2WD',
#  '1994 Acura NSX',
#  '1994 Acura NSX',
#  '1994 Alfa Romeo Spider',
#  '1985 GMC S15 Jimmy 2WD',
#  '1994 Chevrolet Corvette',
#  '1994 Chevrolet Corvette',
#  '1994 Chevrolet Corvette',
#  '1994 Nissan 300ZX',
#  '1994 Nissan 300ZX',
#  '1994 Nissan 300ZX',
#  '1994 Nissan 300ZX',
#  '1994 Dodge Viper',
#  '1994 Ferrari Ferrari 348 TB TS Spider',
#  '1994 Ferrari Ferrari 348 TB TS Spider',
#  '1985 GMC S15 Jimmy 2WD',
#  '1994 Ferrari Ferrari 512 TR',
#  '1994 Honda Civic Del Sol',
#  '1994 Honda Civic Del Sol',
#  '1994 Honda Civic Del Sol',
#  '1994 Honda Civic Del Sol',
#  '1994 Honda Civic Del Sol',
#  '1994 Jaguar XJS Convertible',
#  '1994 Lotus Esprit Turbo',
#  '1994 Mazda MX-5 Miata',
#  '1994 Mazda MX-5 Miata',
#  '1985 Grumman Olson Kubvan',
#  '1994 Mazda RX-7',
#  '1994 Mazda RX-7',
#  '1994 Mercedes-Benz SL320',
#  '1994 Mercedes-Benz SL500',
#  '1994 Mercedes-Benz SL600',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 968',
#  '1994 Porsche 968',
#  '1985 Grumman Olson Kubvan',
#  '1994 Toyota MR2',
#  '1994 Toyota MR2',
#  '1994 Toyota MR2',
#  '1994 Audi Cabriolet',
#  '1994 BMW 318i Convertible',
#  '1994 BMW 318i Convertible',
#  '1994 BMW 325i Convertible',
#  '1994 BMW 325i Convertible',
#  '1994 Mercury Capri',
#  '1994 Mercury Capri',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 Mercury Capri',
#  '1994 Mercedes-Benz E320 Convertible',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 911 Carrera 4 2',
#  '1994 Porsche 911 Turbo',
#  '1994 Porsche 928 GTS',
#  '1994 Porsche 928 GTS',
#  '1994 Porsche 968',
#  '1994 Porsche 968',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 Toyota Paseo',
#  '1994 Toyota Paseo',
#  '1994 Toyota Supra',
#  '1994 Toyota Supra',
#  '1994 Toyota Supra',
#  '1994 Toyota Supra',
#  '1994 Acura Integra',
#  '1994 Acura Integra',
#  '1994 Acura Integra',
#  '1994 Audi 90 quattro',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 BMW 318i 318is',
#  '1994 BMW 318i 318is',
#  '1994 BMW 318i 318is',
#  '1994 BMW 318i 318is',
#  '1994 BMW 325i 325is',
#  '1994 BMW 325i 325is',
#  '1994 BMW 850ci',
#  '1994 BMW 850csi',
#  '1994 Chevrolet Camaro',
#  '1994 Chevrolet Camaro',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 Chevrolet Camaro',
#  '1994 Chevrolet Camaro',
#  '1994 Chevrolet Cavalier',
#  '1994 Chevrolet Cavalier',
#  '1994 Chevrolet Cavalier',
#  '1994 Chevrolet Cavalier',
#  '1994 Chevrolet Sprint',
#  '1994 Chevrolet Sprint',
#  '1994 Chrysler LeBaron Convertible',
#  '1994 Nissan Sentra',
#  '1985 Dodge Colt',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 Nissan Sentra',
#  '1994 Nissan Sentra',
#  '1994 Nissan Sentra',
#  '1994 Nissan 300ZX 2x2',
#  '1994 Nissan 300ZX 2x2',
#  '1994 Dodge Colt',
#  '1994 Dodge Colt',
#  '1994 Dodge Colt',
#  '1994 Dodge Colt',
#  '1994 Dodge Stealth',
#  '1985 Jeep Cherokee Wagoneer',
#  '1994 Dodge Stealth',
#  '1994 Dodge Stealth',
#  '1994 Dodge Stealth',
#  '1994 Dodge Stealth',
#  '1994 Eagle Summit',
#  '1994 Eagle Summit',
#  '1994 Eagle Summit',
#  '1994 Eagle Summit',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1985 Plymouth Voyager 2WD',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1994 Eagle Talon',
#  '1994 Ferrari Ferrari Mondial T Cabriolet',
#  '1994 Ferrari Ferrari Mondial T Cabriolet',
#  '1994 Ford Aspire',
#  '1994 Ford Aspire',
#  '1985 Plymouth Voyager 2WD',
#  '1994 Ford Mustang',
#  '1994 Ford Mustang',
#  '1994 Ford Mustang',
#  '1994 Ford Mustang',
#  '1994 Ford Probe',
#  '1994 Ford Probe',
#  '1994 Ford Probe',
#  '1994 Ford Probe',
#  '1994 Geo Metro',
#  '1994 Geo Metro',
#  '1985 Plymouth Voyager 2WD',
#  '1994 Geo Metro XFI',
#  '1994 Honda Civic',
#  '1994 Honda Civic',
#  '1994 Honda Civic',
#  '1994 Honda Civic',
#  '1994 Honda Civic',
#  '1994 Honda Civic',
#  '1994 Honda Civic HB VX',
#  '1994 Honda Civic HB VX',
#  '1994 Honda Prelude',
#  '1985 Plymouth Voyager 2WD',
#  '1994 Honda Prelude',
#  '1994 Honda Prelude',
#  '1994 Honda Prelude',
#  '1994 Honda Prelude',
#  '1994 Hyundai Excel',
#  '1994 Hyundai Excel',
#  '1994 Hyundai Scoupe',
#  '1994 Hyundai Scoupe',
#  '1994 Hyundai Scoupe',
#  '1994 Infiniti J30',
#  '1985 Plymouth Voyager 2WD',
#  '1994 Jaguar XJS Coupe',
#  '1994 Jaguar XJS Coupe',
#  '1994 Jaguar XJS V12 Coupe',
#  '1994 Lexus SC 300 SC 400',
#  '1994 Lexus SC 300 SC 400',
#  '1994 Lexus SC 300 SC 400',
#  '1994 Mazda MX-3',
#  '1994 Mazda MX-3',
#  '1994 Mazda MX-3',
#  '1994 Mazda MX-3',
#  '1985 American Motors Corporation Eagle 4DR Wagon',
#  '1994 Mazda MX-6',
#  '1994 Mazda MX-6',
#  '1994 Mazda MX-6',
#  '1994 Mazda MX-6',
#  '1994 Mercedes-Benz E320 Coupe',
#  '1994 Mitsubishi Mirage',
#  '1994 Mitsubishi Mirage',
#  '1994 Mitsubishi Mirage',
#  '1994 Mitsubishi Mirage',
#  '1994 Mitsubishi Eclipse',
#  '1985 American Motors Corporation Eagle 4DR Wagon',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi Eclipse',
#  '1994 Mitsubishi 3000 GT',
#  '1994 Mitsubishi 3000 GT',
#  '1994 Mitsubishi 3000 GT',
#  '1985 Chevrolet K10 Blazer 4WD',
#  '1994 Plymouth Colt',
#  '1994 Plymouth Colt',
#  '1994 Plymouth Colt',
#  '1994 Plymouth Colt',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1985 Dodge Colt',
#  '1985 Chevrolet K10 Blazer 4WD',
#  '1994 Plymouth Laser',
#  '1994 Plymouth Laser',
#  '1994 Pontiac Firebird Formula',
#  '1994 Pontiac Firebird Formula',
#  '1994 Pontiac Firebird Formula',
#  '1994 Pontiac Firebird Formula',
#  '1994 Pontiac Firefly',
#  '1994 Pontiac Firefly',
#  '1994 Pontiac Sunbird',
#  '1994 Pontiac Sunbird',
#  '1985 Chevrolet K10 Blazer 4WD',
#  '1994 Pontiac Sunbird',
#  '1994 Pontiac Sunbird',
#  '1994 Rolls-Royce Continental',
#  '1994 Rolls-Royce Corniche IV',
#  '1994 Saab Convertible',
#  '1994 Saab Convertible',
#  '1994 Saab Convertible',
#  '1994 Saab Convertible',
#  '1994 Saab Convertible',
#  '1994 Saturn SC',
#  '1985 Chevrolet Suburban K10 4WD',
#  '1994 Saturn SC',
#  '1994 Saturn SC',
#  '1994 Saturn SC',
#  '1994 Subaru Impreza',
#  '1994 Subaru Impreza',
#  '1994 Subaru Impreza AWD',
#  '1994 Subaru Impreza AWD',
#  '1994 Subaru Justy',
#  '1994 Subaru Justy AWD',
#  '1994 Subaru SVX',
#  '1985 Chevrolet Suburban K10 4WD',
#  '1994 Subaru SVX AWD',
#  '1994 Suzuki Swift',
#  '1994 Suzuki Swift',
#  '1994 Suzuki Swift GT',
#  '1994 Toyota Celica',
#  '1994 Toyota Celica',
#  '1994 Toyota Celica',
#  '1994 Toyota Celica',
#  '1994 Toyota Tercel',
#  '1994 Toyota Tercel',
#  '1985 Chevrolet Suburban K10 4WD',
#  '1994 Toyota Tercel',
#  '1994 Volkswagen Corrado SLC',
#  '1994 Volkswagen Corrado SLC',
#  '1994 Acura Legend',
#  '1994 Acura Legend',
#  '1994 Acura Legend',
#  '1994 Acura Legend',
#  '1994 Acura Vigor',
#  '1994 Acura Vigor',
#  '1994 Alfa Romeo 164',
#  '1985 Chevrolet T10 (S10) Blazer 4WD',
#  '1994 Alfa Romeo 164',
#  '1994 Audi S4',
#  '1994 Audi V8',
#  '1994 Audi 100',
#  '1994 Audi 100',
#  '1994 Audi 100 quattro',
#  '1994 Audi 100 quattro',
#  '1994 Audi 90',
#  '1994 Audi 90',
#  '1994 BMW 525i',
#  '1985 Chevrolet T10 (S10) Blazer 4WD',
#  '1994 BMW 525i',
#  '1994 BMW 530i',
#  '1994 BMW 530i',
#  '1994 BMW 530i',
#  '1994 BMW 530i',
#  '1994 BMW 540i',
#  '1994 Buick Skylark',
#  '1994 Buick Skylark',
#  '1994 Buick Skylark',
#  '1994 Chevrolet Beretta',
#  '1985 Chevrolet T10 (S10) Blazer 4WD',
#  '1994 Chevrolet Beretta',
#  '1994 Chevrolet Beretta',
#  '1994 Chevrolet Beretta',
#  '1994 Chevrolet Beretta',
#  '1994 Chevrolet Beretta',
#  '1994 Chevrolet Corsica',
#  '1994 Chevrolet Corsica',
#  '1994 Chevrolet Corsica',
#  '1994 Chrysler LeBaron',
#  '1994 Chrysler LeBaron',
#  '1985 Chevrolet T10 (S10) Blazer 4WD',
#  '1994 Chrysler LeBaron',
#  '1994 Nissan Altima   Stanza',
#  '1994 Nissan Altima   Stanza',
#  '1994 Dodge Shadow',
#  '1994 Dodge Shadow',
#  '1994 Dodge Shadow',
#  '1994 Dodge Shadow',
#  '1994 Dodge Shadow',
#  '1994 Dodge Shadow',
#  '1994 Ford Escort',
#  '1985 Chevrolet T10 (S10) Blazer 4WD',
#  '1994 Ford Escort',
#  '1994 Ford Escort',
#  '1994 Ford Escort',
#  '1994 Ford Tempo',
#  '1994 Ford Tempo',
#  '1994 Ford Tempo',
#  '1994 Ford Tempo',
#  '1994 Geo Prizm',
#  '1994 Geo Prizm',
#  ...]

# %% [markdown]
# Designates Car Images as the path for the next for loop we are about to run.

# %%
path = Path('/content/gdrive/My Drive/CarImages')

# %% [markdown]
# Creates a new folder for each individual car model to store the car images to be taken from Bing.

# %%
if not path.exists():
    path.mkdir()
    for o in cardb: #change this
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o}') #change this
        download_images(dest, urls=results.attrgot('content_url'))

# %%
path.ls
# Out:
# <bound method Path.ls of Path('cars')>

# %%
show_doc(search_images_bing)
# Out:
# <h4 id="search_images_bing" class="doc_header"><code>search_images_bing</code><a href="https://github.com/fastai/course20/tree/master/fastbook.py#L50" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>search_images_bing</code>(**`key`**, **`term`**, **`min_sz`**=*`128`*)

# %%
append.??
# Out:
#   File "<ipython-input-91-d73044bbea2f>", line 1
#     append.??
#            ^
# SyntaxError: invalid syntax
